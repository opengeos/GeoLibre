# %% [markdown]
# # Welcome to the GeoLibre notebook
#
# This notebook runs entirely in your browser on a [Pyodide](https://pyodide.org) kernel — no server required.
#
# - Run a cell with **Shift+Enter**.
# - Install extra packages on demand, e.g. `%pip install geopandas`.
# - The notebook sits beside the map; in a later release the `geolibre` object will let you script the live map from here.

# %%
print(1 + 1)

# %%
# Packages like geopandas install on demand (first run downloads the wheel):
# %pip install geopandas
import sys
print(sys.version)
